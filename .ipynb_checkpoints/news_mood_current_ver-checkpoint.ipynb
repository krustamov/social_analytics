# %%
import tweepy
import json
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from dateutil import parser
from datetime import timedelta
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re

# %%
api_dir = os.path.dirname((os.path.dirname(os.path.realpath('__file__'))))
file_name = os.path.join(api_dir, "api_keys.json")
data = json.load(open(file_name))

gkey = data['google_places_api_key']
consumer_key = data['twitter_consumer_key']
consumer_secret = data['twitter_consumer_secret']
access_token = data['twitter_access_token']
access_token_secret = data['twitter_access_token_secret']


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

analyzer = SentimentIntensityAnalyzer()

# %%
# Target Account
target_user_1 = "@BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user_1,page=x + 1)

    # Loop through all tweets 
    for tweet in public_tweets:

        #Print Tweets
        #print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        
        sentiments.append({"Date": tweet["created_at"],
                           'User': tweet['user']['name'],
                           'Tweet': tweet['text'],
                            "Compound": compound,
                            "Positive": pos,
                            "Negative": neu,
                            "Neutral": neg,
                            "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
# Convert sentiments to DataFrame
sentiments_pd_1 = pd.DataFrame.from_dict(sentiments)
sentiments_pd_1.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5413  Sat Feb 24 19:59:04 +0000 2018     0.863    0.000     0.137
# 1   -0.4588  Sat Feb 24 19:07:01 +0000 2018     0.842    0.158     0.000
# 2   -0.2023  Sat Feb 24 18:07:04 +0000 2018     0.904    0.096     0.000
# 3    0.0000  Sat Feb 24 17:51:02 +0000 2018     1.000    0.000     0.000
# 4    0.0000  Sat Feb 24 17:50:42 +0000 2018     1.000    0.000     0.000
#
#                                                Tweet  Tweets Ago User
# 0  For 27 centuries, Helen of Troy has been one o...           1  BBC
# 1  This new targeted treatment is designed to def...           2  BBC
# 2  📺🔮 From @ArrestedDev to @TheSimpsons, these ar...           3  BBC
# 3  ❤️ Meet India's Dr Dolittle who runs an orphan...           4  BBC
# 4  RT @BBCOne: “Puberty, periods and pongs!” \n\n...           5  BBC

# %%
# Target Account
target_user_2 = "@CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user_2,page=x + 1)

    # Loop through all tweets 
    for tweet in public_tweets:

        #Print Tweets
        #print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        
        sentiments.append({"Date": tweet["created_at"],
                           'User': tweet['user']['name'],
                           'Tweet': tweet['text'],
                            "Compound": compound,
                            "Positive": pos,
                            "Negative": neu,
                            "Neutral": neg,
                            "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
# Convert sentiments to DataFrame
sentiments_pd_2 = pd.DataFrame.from_dict(sentiments)
sentiments_pd_2.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5093  Fri Feb 23 18:15:40 +0000 2018     0.845      0.0     0.155
# 1    0.0000  Thu Feb 22 19:26:52 +0000 2018     1.000      0.0     0.000
# 2    0.0000  Wed Feb 21 19:20:04 +0000 2018     1.000      0.0     0.000
# 3    0.6808  Wed Feb 21 18:19:25 +0000 2018     0.752      0.0     0.248
# 4    0.4404  Tue Feb 20 19:55:19 +0000 2018     0.884      0.0     0.116
#
#                                                Tweet  Tweets Ago User
# 0  RT @thegoodfight: This is our new favorite thi...           1  CBS
# 1  RT @LivinBiblically: Confession time: have YOU...           2  CBS
# 2  RT @CBSEyeSpeak: Mark your calendars! #CBSEyeS...           3  CBS
# 3  RT @CBSEyeSpeak: Proud to announce a new CBS i...           4  CBS
# 4  RT @LivinBiblically: When you're living by the...           5  CBS

# %%
# Target Account
target_user_3 = "@CNN"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user_3,page=x + 1)

    # Loop through all tweets 
    for tweet in public_tweets:

        #Print Tweets
        #print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        
        sentiments.append({"Date": tweet["created_at"],
                           'User': tweet['user']['name'],
                           'Tweet': tweet['text'],
                            "Compound": compound,
                            "Positive": pos,
                            "Negative": neu,
                            "Neutral": neg,
                            "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
# Convert sentiments to DataFrame
sentiments_pd_3 = pd.DataFrame.from_dict(sentiments)
sentiments_pd_3.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.6597  Sat Feb 24 20:00:05 +0000 2018     0.694    0.306     0.000
# 1   -0.7632  Sat Feb 24 19:50:35 +0000 2018     0.778    0.222     0.000
# 2    0.6369  Sat Feb 24 19:45:12 +0000 2018     0.743    0.000     0.257
# 3   -0.6597  Sat Feb 24 19:30:23 +0000 2018     0.671    0.329     0.000
# 4    0.0000  Sat Feb 24 19:15:08 +0000 2018     1.000    0.000     0.000
#
#                                                Tweet  Tweets Ago User
# 0  Bombs and gunfire rock capital of Somali, kill...           1  CNN
# 1  "We are late to respond to this crisis. Very l...           2  CNN
# 2  JUST IN: The United Nations Security Council u...           3  CNN
# 3  Fear of Russian aggression is driving US milit...           4  CNN
# 4  This is the most "popular" 2020 Democrat at th...           5  CNN

# %%
# Target Account
target_user_4 = "@FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user_4,page=x + 1)

    # Loop through all tweets 
    for tweet in public_tweets:

        #Print Tweets
        #print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        
        sentiments.append({"Date": tweet["created_at"],
                           'User': tweet['user']['name'],
                           'Tweet': tweet['text'],
                            "Compound": compound,
                            "Positive": pos,
                            "Negative": neu,
                            "Neutral": neg,
                            "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
# Convert sentiments to DataFrame
sentiments_pd_4 = pd.DataFrame.from_dict(sentiments)
sentiments_pd_4.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Feb 24 20:01:03 +0000 2018     1.000    0.000     0.000
# 1   -0.2732  Sat Feb 24 19:54:44 +0000 2018     0.709    0.184     0.106
# 2   -0.1531  Sat Feb 24 19:52:56 +0000 2018     0.833    0.167     0.000
# 3    0.0000  Sat Feb 24 19:40:29 +0000 2018     1.000    0.000     0.000
# 4    0.0000  Sat Feb 24 19:40:09 +0000 2018     1.000    0.000     0.000
#
#                                                Tweet  Tweets Ago      User
# 0  Obama Library to cost taxpayers $175 million. ...           1  Fox News
# 1  .@tedcruz losing 2018 fundraising race to like...           2  Fox News
# 2  Watch: Moment when police officers catch falli...           3  Fox News
# 3  .@drmoore on Rev. @BillyGraham: "Billy Graham ...           4  Fox News
# 4  New Pennsylvania Congressional districts. http...           5  Fox News

# %%
# Target Account
target_user_5 = "@nytimes"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user_5,page=x + 1)

    # Loop through all tweets 
    for tweet in public_tweets:

        #Print Tweets
        #print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        
        sentiments.append({"Date": tweet["created_at"],
                           'User': tweet['user']['name'],
                           'Tweet': tweet['text'],
                            "Compound": compound,
                            "Positive": pos,
                            "Negative": neu,
                            "Neutral": neg,
                            "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
# Convert sentiments to DataFrame
sentiments_pd_5 = pd.DataFrame.from_dict(sentiments)
sentiments_pd_5.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.1027  Sat Feb 24 19:52:03 +0000 2018     0.792    0.114     0.094
# 1    0.4023  Sat Feb 24 19:37:05 +0000 2018     0.829    0.000     0.171
# 2    0.7579  Sat Feb 24 19:22:00 +0000 2018     0.609    0.079     0.312
# 3    0.2732  Sat Feb 24 19:10:04 +0000 2018     0.896    0.000     0.104
# 4   -0.2960  Sat Feb 24 18:55:04 +0000 2018     0.901    0.099     0.000
#
#                                                Tweet  Tweets Ago  \
# 0  When Antioch College first introduced its affi...           1
# 1  Trump and his advisers insist they are not wor...           2
# 2  24. “House Party” (1990): The rap duo Kid ’n P...           3
# 3  An executive order says New York governors can...           4
# 4  Meet 4-year-old Bilal. He was found emaciated ...           5
#
#                  User
# 0  The New York Times
# 1  The New York Times
# 2  The New York Times
# 3  The New York Times
# ...

# %%
combined_pd = sentiments_pd_1.append([sentiments_pd_2,sentiments_pd_3,sentiments_pd_4,sentiments_pd_5])
combined_pd
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 0     0.5413  Sat Feb 24 19:59:04 +0000 2018     0.863    0.000     0.137
# 1    -0.4588  Sat Feb 24 19:07:01 +0000 2018     0.842    0.158     0.000
# 2    -0.2023  Sat Feb 24 18:07:04 +0000 2018     0.904    0.096     0.000
# 3     0.0000  Sat Feb 24 17:51:02 +0000 2018     1.000    0.000     0.000
# 4     0.0000  Sat Feb 24 17:50:42 +0000 2018     1.000    0.000     0.000
# 5    -0.2960  Sat Feb 24 16:52:04 +0000 2018     0.727    0.164     0.109
# 6     0.0000  Sat Feb 24 16:20:09 +0000 2018     1.000    0.000     0.000
# 7     0.2500  Sat Feb 24 15:13:02 +0000 2018     0.905    0.000     0.095
# 8     0.0000  Sat Feb 24 13:54:12 +0000 2018     1.000    0.000     0.000
# 9     0.0000  Sat Feb 24 13:07:02 +0000 2018     1.000    0.000     0.000
# 10   -0.6428  Sat Feb 24 11:59:01 +0000 2018     0.712    0.288     0.000
# 11    0.9523  Sat Feb 24 10:47:04 +0000 2018     0.392    0.000     0.608
# ...

# %%
# Save the DataFrame as a csv
combined_pd.to_csv("social_analytics_data.csv", encoding="utf-8", index=False)

# %%
#colors = {'BBC':'red', 'CBS':'blue', 'CNN':'green', 'FoxNews':'purple', 'nytimes':'orange'}

# %%
# Build a scatter plot for each data type

plt.figure(figsize=(12,7))

plt.scatter(combined_pd[combined_pd['User'] == 'BBC']['Tweets Ago'], 
            combined_pd[combined_pd['User'] == 'BBC']['Compound'],
            edgecolor="black", linewidths=1, marker="o",s=100,
            alpha=0.8, label="BBC", color = 'k')

plt.scatter(combined_pd[combined_pd['User'] == 'CBS']['Tweets Ago'], 
            combined_pd[combined_pd['User'] == 'CBS']['Compound'],
            edgecolor="black", linewidths=1, marker="o",s=100,
            alpha=0.8, label="CBS", color = 'b')

plt.scatter(combined_pd[combined_pd['User'] == 'CNN']['Tweets Ago'], 
            combined_pd[combined_pd['User'] == 'CNN']['Compound'],
            edgecolor="black", linewidths=1, marker="o",s=100,
            alpha=0.8, label="CNN", color = 'r')

plt.scatter(combined_pd[combined_pd['User'] == 'Fox News']['Tweets Ago'], 
            combined_pd[combined_pd['User'] == 'Fox News']['Compound'],
            edgecolor="green", linewidths=1, marker="o",s=100,
            alpha=0.8, label="Fox News", color = '#98FB98')

plt.scatter(combined_pd[combined_pd['User'] == 'The New York Times']['Tweets Ago'], 
            combined_pd[combined_pd['User'] == 'The New York Times']['Compound'],
            edgecolor="green", linewidths=1, marker="o",s=100,
            alpha=0.8, label="The New York Times", color = '#FFA07A')


# Incorporate the other graph properties
plt.title('Sentiment Analysis of Media Tweets (20180223)')
plt.ylabel('Tweet Polarity')
plt.xlabel('Tweets Ago')
plt.legend(loc='lower left', shadow=True)
plt.grid(True)
plt.xlim([0, 101])
plt.ylim([-1, 1])

# Save the figure
plt.savefig("social_analytics.png")

# Show plot
plt.show()

# %%
test_df = combined_pd.groupby('User')['Compound']

# %%
test_df.head()
test_df = pd.DataFrame(combined_pd.groupby('User')['Compound'].mean())
test_df = test_df.rename(columns={'Compound': 'Compound Score'})
#test_df = test_df.reset_index()
test_df.head()
# Out:
#                     Compound Score
# User
# BBC                       0.073518
# CBS                       0.332959
# CNN                      -0.033581
# Fox News                 -0.005260
# The New York Times        0.032503

# %%
with plt.style.context('seaborn-darkgrid'):
    tweet_plot = test_df['Compound Score'].plot(kind="bar", figsize=(12,7))
    tweet_plot.set_title("Overall Media Sentiment based on Twitter (20180223)")
    tweet_plot.set_ylabel("Tweet Polarity)")
    plt.legend(loc='lower left', shadow=True)
    plt.savefig('social_analytics.png')
    plt.show()

# %% [markdown]
# Observable Trends:
# 1. CBS has the most positive compund score
# 2. CNN Times has the most negative compund score
# 3.
